# %%
# import required libraries
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl

# %matplotlib inline

# %%
import torch
from torchvision import datasets
from torchvision import transforms

# Tensor transform, will use to transform data to Tensor datatype
transform = transforms.ToTensor()

# SVHN training datasets - built into PyTorch "datasets" library
svhn_train = datasets.SVHN(root='./data', split='train', download=True, transform=transform)

batch_size = 128
num_workers = 0

# create DataLoaders for SVHN dataset - help batch data into batches of specific size
train_loader = torch.utils.data.DataLoader(dataset=svhn_train,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=num_workers)

# %%
# take one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.transpose(images[idx], (1, 2, 0)))
    # print out the correct label for each image
    # .item() gets the value contained in a Tensor
    ax.set_title(str(labels[idx].item()))
    
# Note that we are working with 1 number that is (usually) most central to the image, 
# even if there are more numbers in the image it is labled as a single number   
# Check out image with 102 in it, it is labeled as 1...

# %%
from PIL import Image
import cv2
import os
#use cv2 to resize the image we find.
img_path='./data/house number'
#create our own little dataset
for img_id in range(len(os.listdir(img_path))):
    #Several steps to load all the img arrays in our own dataset 
    im = Image.open('./data/house number/{}.jpg'.format(img_id+1))#index for x start from 1
    #im.show()
    im_array = np.array(im)

    im_array =cv2.resize(im_array, (32,32), interpolation = cv2.INTER_CUBIC)
    #plt.imshow(im_array)
    im_array=np.transpose(im_array, (2, 0, 1))
    if(img_id==0):
        im_arrays=im_array.reshape(1,3,32,32)
    else:
        im_arrays=np.concatenate([im_arrays,im_array.reshape(1,3,32,32)])
im_arrays=im_arrays/255
print(im_arrays.shape)#30 images with proper size
# Out:
# (30, 3, 32, 32)

# %%
#Use matplotlib to preview the resized image.
plt.imshow(np.transpose(im_arrays[0],(1,2,0)))

# %%
# current range
img = images[0]

print('Min: ', img.min())
print('Max: ', img.max())
# Out:
# Min:  tensor(0.0078)
# Max:  tensor(0.7647)

# %%
# The output of our G will be tanh activated e.i. on a range from [-1 1], 
# We need to rescale training images to that range. (Currently: [0 1])
def scale(xx, feature_range=(-1, 1)):
    ''' INPUT: image xx scaled to [0 1]
       OUTPUT: image scaled [-1 1] '''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    xx = xx * (max - min) + min
    return xx

# %%
# scale image
scaled_img = scale(img)

print('Scaled min: ', scaled_img.min())
print('Scaled max: ', scaled_img.max())
# Out:
# Scaled min:  tensor(-0.9843)
# Scaled max:  tensor(0.5294)

# %%
# Home numbers dataset is more complex than MNIST, we will train a deeper network 
# to identify patterns in these images and generate new ones. Use a series of 
# convolutional and transpose convolutional layers in the discriminator and generator,
# respectively. Use batch normalization to get convolutional networks to train faster/beter.

# %%
import torch.nn as nn
import torch.nn.functional as F

# Each layer should be convolution -> batch norm (optional) -> leaky ReLU
# conv function will put these layers together sequentialy.
# Use PyTorch's Sequential container which takes in a list of layers and creates 
# layers according to the order that they are passed in to the Sequential constructor.
# A strided convolutional layer and an optional batch norm layer
#
# https://pytorch.org/docs/stable/nn.html#batchnorm2d
# https://pytorch.org/docs/stable/nn.html#sequential
#
# We will use kernel_size = 4 & stride = 2, will reduce size of image by 2
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    # bias is set to False, so the layers are not offset by any amount
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
# Use batch normalization with nn.BatchNorm2d on each layer except 
# the 1st convolutional layer and final linear output layer.
# In the DCGAN paper, they did all the downsampling using only strided 
# convolutional layers with no maxpooling layers

class Discriminator(nn.Module):
    def __init__(self, conv_dim=32):
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        # 32x32 input, 16x16 output
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False) # 1st layer, no batch_norm 
        self.conv2 = conv(conv_dim, conv_dim*2, 4)   # 8x8 output
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4) # 4x4 output
        
        # final fully-connected layer - produces 1 output (par 2)
        self.fc = nn.Linear(conv_dim*4*4*4, 1)

    def forward(self, xx):
        # all hidden layers + leaky relu activation
        out = F.leaky_relu(self.conv1(xx),  0.2)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = F.leaky_relu(self.conv3(out), 0.2)
        
        # flatten
        out = out.view(-1, self.conv_dim*4*4*4)
        
        # final output layer
        out = self.fc(out)        
        return out

# %%
# define a function that will allow us to do:
# transpose convolution -> batch norm (optional: T/F) -> ReLU
# Use kernel_size 4 & stride 2 for transpose convolutions

def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Create a transposed-convolutional layer with optional batch normalization """
    # create a sequence of transpose + optional batch norm layers
    layers = [] # empty list of layers
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
# In G 1st layer is a fully connected layer which is reshaped into a deep and narrow layer, eg. 4x4x512
# Then use batch norm & leaky ReLU activation
# Next is a series of transpose convolutional layers where you typically halve the depth 
# and double the width and height of the previous layer
# Apply batch normalization and ReLU to all but the last hidden layer. Where we apply a tanh activation

# Input: randomly generated vector z
# Output tanh values of size 32x32 which is the size of the SVHN images

class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim=32):
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        # first fully-connected layer, 
        # params: latent verctor z & produces a layer 4x4x128
        #         4x4 part defined in the forward step below
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)

        # transpose conv layers, kernel_size = 4,
        # desired depth for RGB image is 3
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)
        

    def forward(self, xx):
        # fully-connected + reshape 
        out = self.fc(xx)
        # params: batch_size, depth, 4, 4
        # -1 is a place holder for batch size
        # 128 - depth as defined by the convolutional dimention
        out = out.view(-1, self.conv_dim*4, 4, 4) # (batch_size, depth, 4, 4)
        
        # hidden transpose conv layers + relu
        out = F.relu(self.t_conv1(out))
        out = F.relu(self.t_conv2(out))
        
        # last layer + tanh activation
        out = self.t_conv3(out)
        out = F.tanh(out)
        
        return out

# %%
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)

print(D)
print()
print(G)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %%
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')
# Out:
# GPU available for training. Models moved to GPU

# %%
# Define Losses
# For D the total loss is the sum of the losses for real and fake images:
#     d_loss = d_real_loss + d_fake_loss
# The losses will by binary cross entropy loss with logits (BCEWithLogitsLoss). 
# BCEWithLogitsLoss combines a sigmoid activation function and a binary cross entropy loss
# We want D to output 1 for real images and 0 for fake images, make sure the losses to reflect that.
#
# For real images we want D(real_images) = 1, i.e. classify real images as = 1. 
# D's loss for the fake data is D(fake_images) = 0, where fake images are G's output, fake_images = G(z).
#
# For G the loss is similar but with labels flipped. G's goal is to get D(fake_images) = 1. 
# In this case, the labels are flipped to represent that the generator is trying to fool the discriminator 
# into thinking that the fake images it generates are real


def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
# Optimisers, similar to what we did before

import torch.optim as optim

# Take a look at osme fake images generated during traning

# helper function for viewing a list of images, for us they are intermediate fake images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img +1)*255 / (2)).astype(np.uint8) # rescale to pixel range (0-255)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
#only use my 30 pictures to train the network without using the given dataset.

D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf
lr = 0.0002
beta1=0.5
beta2=0.999 # default value

d_lambda = lambda epoch: 0.95 * epoch# After each epoch, the learning rate decrease 5%

g_lambda = lambda epoch: 0.95 * epoch# After each epoch, the learning rate decrease 5%
# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr*0.5, [beta1, beta2])
d_scheduler=optim.lr_scheduler.LambdaLR(d_optimizer, lr_lambda=d_lambda)#define scheduler for d_optimizer and g_optimizer
g_optimizer = optim.Adam(G.parameters(), lr*0.8, [beta1, beta2])
g_scheduler=optim.lr_scheduler.LambdaLR(g_optimizer, lr_lambda=g_lambda)#define scheduler for d_optimizer and g_optimizer





import pickle as pkl
num_epochs = 10000
samples = []
losses = []
print_every = 500

batch_size = im_arrays.shape[0]#I read it as numpy, so shape will be used instead of size
real_images=scale(im_arrays) 
real_images=torch.from_numpy(real_images).type(torch.FloatTensor)
for epoch in range(num_epochs):
    # train D
    d_optimizer.zero_grad()

    # 1. Train with real images
    # Compute the D losses on real images 
    if train_on_gpu:
        real_images = real_images.cuda()

    D_real = D(real_images)
    d_real_loss = real_loss(D_real)

    # 2. Train with fake images
    # Generate fake images
    zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
    zz = torch.from_numpy(zz).float()
    # move to GPU, if available
    if train_on_gpu:
        zz = zz.cuda()
    fake_images = G(zz)

    # Compute the D losses on fake images            
    D_fake = D(fake_images)
    d_fake_loss = fake_loss(D_fake)

    # add up loss and perform backprop
    d_loss = d_real_loss + d_fake_loss
    d_loss.backward()
    d_optimizer.step()
    # train G
    g_optimizer.zero_grad()

    # 1. Train with fake images and flipped labels 
    # Generate fake images
    zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
    zz = torch.from_numpy(zz).float()
    if train_on_gpu:
        zz = zz.cuda()
    fake_images = G(zz)

    # Compute the D losses on fake images 
    # using flipped labels
    D_fake = D(fake_images)
    g_loss = real_loss(D_fake) # use real loss to flip labels

    # perform backprop
    g_loss.backward()
    g_optimizer.step()

    # Print some loss stats
    if epoch%100 == 0:
        # append D loss and G loss
        losses.append((d_loss.item(), g_loss.item()))
        # print discriminator and generator loss
        print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    if(epoch%500==0):
        d_scheduler.step()
        g_scheduler.step()
# AFTER EACH EPOCH    
# generate and save fake images
G.eval() # eval mode for generating samples
# eval mode - batch_norm & drop out behave differently in generating new samples
# batch_norm should use population statistics instead of batch statistics in eval
# dropout should not drop any nodes during testing
# Out:
# GPU available for training. Models moved to GPU
# Epoch [    1/10000] | d_loss: 1.4038 | g_loss: 0.8040
# Epoch [  101/10000] | d_loss: 0.2104 | g_loss: 2.4614
# Epoch [  201/10000] | d_loss: 0.1113 | g_loss: 3.3460
# Epoch [  301/10000] | d_loss: 0.0967 | g_loss: 3.5297
# Epoch [  401/10000] | d_loss: 0.0725 | g_loss: 4.2341
# Epoch [  501/10000] | d_loss: 0.0459 | g_loss: 4.2340
# Epoch [  601/10000] | d_loss: 0.0536 | g_loss: 4.7977
# Epoch [  701/10000] | d_loss: 0.0423 | g_loss: 4.7339
# Epoch [  801/10000] | d_loss: 0.0294 | g_loss: 4.8893
# Epoch [  901/10000] | d_loss: 0.0185 | g_loss: 5.3124
# Epoch [ 1001/10000] | d_loss: 0.0174 | g_loss: 5.4383
# Epoch [ 1101/10000] | d_loss: 0.0136 | g_loss: 6.6284
# Epoch [ 1201/10000] | d_loss: 0.0492 | g_loss: 5.8703
# Epoch [ 1301/10000] | d_loss: 0.0401 | g_loss: 5.6326
# Epoch [ 1401/10000] | d_loss: 0.0175 | g_loss: 5.5913
# Epoch [ 1501/10000] | d_loss: 0.0110 | g_loss: 6.1049
# Epoch [ 1601/10000] | d_loss: 0.0103 | g_loss: 6.7099
# Epoch [ 1701/10000] | d_loss: 0.0073 | g_loss: 6.8036
# Epoch [ 1801/10000] | d_loss: 0.0051 | g_loss: 7.3215
# Epoch [ 1901/10000] | d_loss: 0.0037 | g_loss: 6.6087
# Epoch [ 2001/10000] | d_loss: 0.0042 | g_loss: 7.1786
# Epoch [ 2101/10000] | d_loss: 0.0039 | g_loss: 7.6567
# Epoch [ 2201/10000] | d_loss: 0.0036 | g_loss: 7.1264
# Epoch [ 2301/10000] | d_loss: 0.0039 | g_loss: 8.3985
# Epoch [ 2401/10000] | d_loss: 0.0027 | g_loss: 7.6875
# Epoch [ 2501/10000] | d_loss: 0.0018 | g_loss: 7.0226
# Epoch [ 2601/10000] | d_loss: 0.0017 | g_loss: 7.7103
# Epoch [ 2701/10000] | d_loss: 0.0460 | g_loss: 6.1007
# Epoch [ 2801/10000] | d_loss: 0.1281 | g_loss: 7.3090
# Epoch [ 6901/10000] | d_loss: 0.0026 | g_loss: 8.4869
# Epoch [ 7001/10000] | d_loss: 0.4721 | g_loss: 21.0080
# Epoch [ 7101/10000] | d_loss: 0.0577 | g_loss: 12.3436
# Epoch [ 7201/10000] | d_loss: 0.0212 | g_loss: 5.5949
# Epoch [ 7301/10000] | d_loss: 0.0135 | g_loss: 5.3865
# Epoch [ 7401/10000] | d_loss: 0.0122 | g_loss: 6.2954
# Epoch [ 7501/10000] | d_loss: 0.0078 | g_loss: 7.1893
# Epoch [ 7601/10000] | d_loss: 0.0087 | g_loss: 7.9241
# Epoch [ 7701/10000] | d_loss: 0.0057 | g_loss: 7.7356
# Epoch [ 7801/10000] | d_loss: 0.0028 | g_loss: 8.9045
# Epoch [ 7901/10000] | d_loss: 0.0040 | g_loss: 6.5484
# Epoch [ 8001/10000] | d_loss: 0.0045 | g_loss: 7.8220
# Epoch [ 8101/10000] | d_loss: 0.0030 | g_loss: 7.1576
# Epoch [ 8201/10000] | d_loss: 0.0056 | g_loss: 7.6430
# Epoch [ 8301/10000] | d_loss: 0.0041 | g_loss: 8.1485
# Epoch [ 8401/10000] | d_loss: 0.0011 | g_loss: 8.1239
# Epoch [ 8501/10000] | d_loss: 0.0024 | g_loss: 11.1351
# Epoch [ 8601/10000] | d_loss: 0.0014 | g_loss: 7.9372
# Epoch [ 8701/10000] | d_loss: 0.0018 | g_loss: 8.4754
# Epoch [ 8801/10000] | d_loss: 0.0011 | g_loss: 8.7389
# Epoch [ 8901/10000] | d_loss: 0.0005 | g_loss: 8.4136
# Epoch [ 9001/10000] | d_loss: 0.0010 | g_loss: 8.3848
# Epoch [ 9101/10000] | d_loss: 0.0006 | g_loss: 8.6250
# Epoch [ 9201/10000] | d_loss: 0.0008 | g_loss: 7.7102
# Epoch [ 9301/10000] | d_loss: 0.0340 | g_loss: 6.8071
# Epoch [ 9401/10000] | d_loss: 0.0985 | g_loss: 9.2670
# Epoch [ 9501/10000] | d_loss: 0.0371 | g_loss: 8.6183
# Epoch [ 9601/10000] | d_loss: 0.0292 | g_loss: 7.0872
# Epoch [ 9701/10000] | d_loss: 1.7395 | g_loss: 36.6853
# Epoch [ 9801/10000] | d_loss: 0.0116 | g_loss: 6.3280
# Epoch [ 9901/10000] | d_loss: 0.0128 | g_loss: 5.6622
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %%
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

if train_on_gpu:
    fixed_z = fixed_z.cuda()
samples_z = G(fixed_z)
samples.append(samples_z)
G.train() # switch back to training mode
_ = view_samples(-1, samples)#new result1

torch.save(D, 'D_my.pkl')  # save entire net
torch.save(G, 'G_my.pkl')  # save entire net
#After 10000 rounds of train. The output is acceptable since my choose images have different background and number
#We can easily find some clear background and number in the generated images.
# Out:
# D:\ANACONDA\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Discriminator. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# D:\ANACONDA\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Generator. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')
    
# Optimisers, similar to what we did before

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf
lr = 0.0002# Use bigger lr
beta1=0.5
beta2=0.999 # default value

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])

g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# Discriminator training
#   Compute the discriminator loss on real, training images
#   Generate fake images
#   Compute the discriminator loss on fake, generated images
#   Add up real and fake loss
#   Perform backpropagation + an optimization step to update the discriminator's weights
#
# Generator training
#   Generate fake images
#   Compute the discriminator loss on fake images, using flipped labels!
#   Perform backpropagation + an optimization step to update the generator's weights


import pickle as pkl # to save intermediate fake images

# training hyperparams
num_epochs = 50 # will run for a 2-4 hours

# keep track of loss and fake samples
samples = []
losses = []
print_every = 300

# Get some fixed data for evaluating the model's performance as we train
# Keep these images constant
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        # important rescaling step
        real_images = scale(real_images)
        
        # train D
        d_optimizer.zero_grad()
        
        # 1. Train with real images
        # Compute the D losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)
        
        # 2. Train with fake images
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        # move to GPU, if available
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images            
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # train G
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels 
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images 
        # using flipped labels
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
        
        # Print some loss stats
        if batch_i % print_every == 0:
            # append D loss and G loss
            losses.append((d_loss.item(), g_loss.item()))
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))


    # AFTER EACH EPOCH    
    # generate and save fake images
    G.eval() # eval mode for generating samples
    # eval mode - batch_norm & drop out behave differently in generating new samples
    # batch_norm should use population statistics instead of batch statistics in eval
    # dropout should not drop any nodes during testing
    
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # switch back to training mode

# Save training generator samples
with open('fake_images.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# GPU available for training. Models moved to GPU
# Epoch [    1/   50] | d_loss: 1.3919 | g_loss: 0.8538
# Epoch [    1/   50] | d_loss: 0.2285 | g_loss: 2.6989
# Epoch [    2/   50] | d_loss: 0.3443 | g_loss: 3.4571
# Epoch [    2/   50] | d_loss: 0.3660 | g_loss: 3.1577
# Epoch [    3/   50] | d_loss: 0.7042 | g_loss: 3.8687
# Epoch [    3/   50] | d_loss: 0.3881 | g_loss: 2.7048
# Epoch [    4/   50] | d_loss: 0.5281 | g_loss: 1.4350
# Epoch [    4/   50] | d_loss: 0.5380 | g_loss: 1.8193
# Epoch [    5/   50] | d_loss: 0.3305 | g_loss: 2.3934
# Epoch [    5/   50] | d_loss: 0.2615 | g_loss: 3.0619
# Epoch [    6/   50] | d_loss: 0.5213 | g_loss: 1.3950
# Epoch [    6/   50] | d_loss: 0.7842 | g_loss: 2.9328
# Epoch [    7/   50] | d_loss: 0.7766 | g_loss: 2.9187
# Epoch [    7/   50] | d_loss: 0.1656 | g_loss: 3.3603
# Epoch [    8/   50] | d_loss: 0.1615 | g_loss: 2.7486
# Epoch [    8/   50] | d_loss: 0.2297 | g_loss: 3.5865
# Epoch [    9/   50] | d_loss: 0.9383 | g_loss: 5.7600
# Epoch [    9/   50] | d_loss: 0.1885 | g_loss: 3.5900
# Epoch [   10/   50] | d_loss: 0.3392 | g_loss: 4.3923
# Epoch [   10/   50] | d_loss: 0.1543 | g_loss: 3.8980
# Epoch [   11/   50] | d_loss: 0.1355 | g_loss: 3.2337
# Epoch [   11/   50] | d_loss: 0.1452 | g_loss: 2.4796
# Epoch [   12/   50] | d_loss: 0.1661 | g_loss: 2.4823
# Epoch [   12/   50] | d_loss: 0.1099 | g_loss: 4.3565
# Epoch [   13/   50] | d_loss: 0.0810 | g_loss: 3.2447
# Epoch [   13/   50] | d_loss: 0.1032 | g_loss: 3.3821
# Epoch [   14/   50] | d_loss: 0.1380 | g_loss: 5.0528
# Epoch [   14/   50] | d_loss: 0.1708 | g_loss: 3.5319
# Epoch [   36/   50] | d_loss: 0.0863 | g_loss: 3.8079
# Epoch [   36/   50] | d_loss: 0.0910 | g_loss: 3.1872
# Epoch [   37/   50] | d_loss: 0.1204 | g_loss: 3.5565
# Epoch [   37/   50] | d_loss: 0.2559 | g_loss: 5.8360
# Epoch [   38/   50] | d_loss: 0.0794 | g_loss: 5.1657
# Epoch [   38/   50] | d_loss: 0.0931 | g_loss: 3.4693
# Epoch [   39/   50] | d_loss: 0.0816 | g_loss: 4.4037
# Epoch [   39/   50] | d_loss: 0.0874 | g_loss: 4.3678
# Epoch [   40/   50] | d_loss: 0.0878 | g_loss: 3.8772
# Epoch [   40/   50] | d_loss: 0.0669 | g_loss: 3.7520
# Epoch [   41/   50] | d_loss: 0.1044 | g_loss: 5.2964
# Epoch [   41/   50] | d_loss: 0.0367 | g_loss: 5.3666
# Epoch [   42/   50] | d_loss: 0.1529 | g_loss: 3.5795
# Epoch [   42/   50] | d_loss: 0.0796 | g_loss: 4.7738
# Epoch [   43/   50] | d_loss: 0.0525 | g_loss: 4.1616
# Epoch [   43/   50] | d_loss: 0.0538 | g_loss: 4.7187
# Epoch [   44/   50] | d_loss: 0.9373 | g_loss: 6.5390
# Epoch [   44/   50] | d_loss: 0.1028 | g_loss: 3.1490
# Epoch [   45/   50] | d_loss: 0.4033 | g_loss: 3.0211
# Epoch [   45/   50] | d_loss: 0.0608 | g_loss: 5.8579
# Epoch [   46/   50] | d_loss: 0.0433 | g_loss: 4.4246
# Epoch [   46/   50] | d_loss: 0.0824 | g_loss: 3.8025
# Epoch [   47/   50] | d_loss: 0.1050 | g_loss: 4.3822
# Epoch [   47/   50] | d_loss: 0.0412 | g_loss: 5.0774
# Epoch [   48/   50] | d_loss: 1.1914 | g_loss: 9.1631
# Epoch [   48/   50] | d_loss: 0.0487 | g_loss: 5.2817
# Epoch [   49/   50] | d_loss: 0.0378 | g_loss: 4.3991
# Epoch [   49/   50] | d_loss: 0.0467 | g_loss: 4.0096
# Epoch [   50/   50] | d_loss: 0.1670 | g_loss: 5.5189
# Epoch [   50/   50] | d_loss: 0.0753 | g_loss: 4.4008

# %%
_ = view_samples(-1, samples)#new result1
#Original parameters as the baseline
torch.save(D, 'D0.pkl')  # save entire net
torch.save(G, 'G0.pkl')  # save entire net

# %%
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')
    
# Optimisers, similar to what we did before

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf
lr = 0.0002# Use bigger lr
beta1=0.5
beta2=0.999 # default value

d_lambda = lambda epoch: 0.95 * epoch# After each epoch, the learning rate decrease 5%

g_lambda = lambda epoch: 0.95 * epoch# After each epoch, the learning rate decrease 5%
# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
d_scheduler=optim.lr_scheduler.LambdaLR(d_optimizer, lr_lambda=d_lambda)#define scheduler for d_optimizer and g_optimizer
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])
g_scheduler=optim.lr_scheduler.LambdaLR(g_optimizer, lr_lambda=g_lambda)#define scheduler for d_optimizer and g_optimizer

# Discriminator training
#   Compute the discriminator loss on real, training images
#   Generate fake images
#   Compute the discriminator loss on fake, generated images
#   Add up real and fake loss
#   Perform backpropagation + an optimization step to update the discriminator's weights
#
# Generator training
#   Generate fake images
#   Compute the discriminator loss on fake images, using flipped labels!
#   Perform backpropagation + an optimization step to update the generator's weights


import pickle as pkl # to save intermediate fake images

# training hyperparams
num_epochs = 50 # will run for a 2-4 hours

# keep track of loss and fake samples
samples = []
losses = []
print_every = 300

# Get some fixed data for evaluating the model's performance as we train
# Keep these images constant
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        # important rescaling step
        real_images = scale(real_images)
        
        # train D
        d_optimizer.zero_grad()
        
        # 1. Train with real images
        # Compute the D losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)
        
        # 2. Train with fake images
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        # move to GPU, if available
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images            
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # train G
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels 
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images 
        # using flipped labels
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
        
        # Print some loss stats
        if batch_i % print_every == 0:
            # append D loss and G loss
            losses.append((d_loss.item(), g_loss.item()))
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    d_scheduler.step()
    g_scheduler.step()
    # AFTER EACH EPOCH    
    # generate and save fake images
    G.eval() # eval mode for generating samples
    # eval mode - batch_norm & drop out behave differently in generating new samples
    # batch_norm should use population statistics instead of batch statistics in eval
    # dropout should not drop any nodes during testing
    
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # switch back to training mode

# Save training generator samples
with open('fake_images.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# GPU available for training. Models moved to GPU
# Epoch [    1/   50] | d_loss: 1.4658 | g_loss: 0.5065
# Epoch [    1/   50] | d_loss: 1.4557 | g_loss: 0.5370
# Epoch [    2/   50] | d_loss: 1.4566 | g_loss: 0.7520
# Epoch [    2/   50] | d_loss: 0.5070 | g_loss: 3.3299
# Epoch [    3/   50] | d_loss: 0.6258 | g_loss: 1.3203
# Epoch [    3/   50] | d_loss: 1.2759 | g_loss: 3.1140
# Epoch [    4/   50] | d_loss: 0.6760 | g_loss: 4.6741
# Epoch [    4/   50] | d_loss: 1.6860 | g_loss: 7.4478
# Epoch [    5/   50] | d_loss: 0.2529 | g_loss: 3.9332
# Epoch [    5/   50] | d_loss: 1.6484 | g_loss: 0.4326
# Epoch [    6/   50] | d_loss: 0.5899 | g_loss: 2.1027
# Epoch [    6/   50] | d_loss: 0.4255 | g_loss: 2.1722
# Epoch [    7/   50] | d_loss: 1.2399 | g_loss: 1.1047
# Epoch [    7/   50] | d_loss: 0.5493 | g_loss: 1.7650
# Epoch [    8/   50] | d_loss: 0.9738 | g_loss: 2.4919
# Epoch [    8/   50] | d_loss: 0.6519 | g_loss: 1.8307
# Epoch [    9/   50] | d_loss: 0.5022 | g_loss: 1.8069
# Epoch [    9/   50] | d_loss: 0.4682 | g_loss: 2.6372
# Epoch [   10/   50] | d_loss: 0.7127 | g_loss: 2.4296
# Epoch [   10/   50] | d_loss: 0.5045 | g_loss: 2.5116
# Epoch [   11/   50] | d_loss: 0.4293 | g_loss: 3.2178
# Epoch [   11/   50] | d_loss: 0.4793 | g_loss: 1.8502
# Epoch [   12/   50] | d_loss: 0.3990 | g_loss: 2.4252
# Epoch [   12/   50] | d_loss: 0.5418 | g_loss: 2.0693
# Epoch [   13/   50] | d_loss: 1.0981 | g_loss: 2.4842
# Epoch [   13/   50] | d_loss: 0.4575 | g_loss: 1.8187
# Epoch [   14/   50] | d_loss: 0.8443 | g_loss: 1.3425
# Epoch [   14/   50] | d_loss: 0.2769 | g_loss: 2.4656
# Epoch [   36/   50] | d_loss: 0.6537 | g_loss: 4.8778
# Epoch [   36/   50] | d_loss: 0.0969 | g_loss: 4.5625
# Epoch [   37/   50] | d_loss: 0.2354 | g_loss: 3.8511
# Epoch [   37/   50] | d_loss: 0.5704 | g_loss: 7.6859
# Epoch [   38/   50] | d_loss: 0.0568 | g_loss: 6.2968
# Epoch [   38/   50] | d_loss: 0.0404 | g_loss: 5.2692
# Epoch [   39/   50] | d_loss: 0.1653 | g_loss: 4.7869
# Epoch [   39/   50] | d_loss: 0.8904 | g_loss: 2.9761
# Epoch [   40/   50] | d_loss: 0.4566 | g_loss: 3.6663
# Epoch [   40/   50] | d_loss: 0.1058 | g_loss: 3.2203
# Epoch [   41/   50] | d_loss: 0.2627 | g_loss: 3.7501
# Epoch [   41/   50] | d_loss: 0.0575 | g_loss: 6.5146
# Epoch [   42/   50] | d_loss: 1.5276 | g_loss: 1.2479
# Epoch [   42/   50] | d_loss: 0.0710 | g_loss: 5.3378
# Epoch [   43/   50] | d_loss: 0.4423 | g_loss: 3.6026
# Epoch [   43/   50] | d_loss: 0.1324 | g_loss: 6.2496
# Epoch [   44/   50] | d_loss: 0.4678 | g_loss: 4.6702
# Epoch [   44/   50] | d_loss: 2.1590 | g_loss: 2.6430
# Epoch [   45/   50] | d_loss: 0.0554 | g_loss: 4.0100
# Epoch [   45/   50] | d_loss: 0.1531 | g_loss: 7.5496
# Epoch [   46/   50] | d_loss: 0.2016 | g_loss: 5.0796
# Epoch [   46/   50] | d_loss: 0.3392 | g_loss: 6.2621
# Epoch [   47/   50] | d_loss: 0.1353 | g_loss: 4.8269
# Epoch [   47/   50] | d_loss: 0.3863 | g_loss: 7.7274
# Epoch [   48/   50] | d_loss: 0.2079 | g_loss: 5.3409
# Epoch [   48/   50] | d_loss: 0.1740 | g_loss: 3.9213
# Epoch [   49/   50] | d_loss: 0.5133 | g_loss: 11.2994
# Epoch [   49/   50] | d_loss: 0.1689 | g_loss: 3.7296
# Epoch [   50/   50] | d_loss: 0.1382 | g_loss: 6.2062
# Epoch [   50/   50] | d_loss: 0.1411 | g_loss: 5.1895

# %%
_ = view_samples(-1, samples)#new result1
#After each epoch , the learning rate of G and D decrese by 5% 
#50 epochs
torch.save(D, 'D1.pkl')  # save entire net
torch.save(G, 'G1.pkl')  # save entire net

# %%
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')
    
# Optimisers, similar to what we did before

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf
lr = 0.0003# Use bigger lr
beta1=0.5
beta2=0.999 # default value

d_lambda = lambda epoch: 0.95 * epoch# After each epoch, the learning rate decrease 5%

g_lambda = lambda epoch: 0.97 * epoch# After each epoch, the learning rate decrease 3%
# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
d_scheduler=optim.lr_scheduler.LambdaLR(d_optimizer, lr_lambda=d_lambda)#define scheduler for d_optimizer and g_optimizer
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])
g_scheduler=optim.lr_scheduler.LambdaLR(g_optimizer, lr_lambda=g_lambda)#define scheduler for d_optimizer and g_optimizer

# Discriminator training
#   Compute the discriminator loss on real, training images
#   Generate fake images
#   Compute the discriminator loss on fake, generated images
#   Add up real and fake loss
#   Perform backpropagation + an optimization step to update the discriminator's weights
#
# Generator training
#   Generate fake images
#   Compute the discriminator loss on fake images, using flipped labels!
#   Perform backpropagation + an optimization step to update the generator's weights


import pickle as pkl # to save intermediate fake images

# training hyperparams
num_epochs = 50 # will run for a 2-4 hours

# keep track of loss and fake samples
samples = []
losses = []
print_every = 300

# Get some fixed data for evaluating the model's performance as we train
# Keep these images constant
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        # important rescaling step
        real_images = scale(real_images)
        
        # train D
        d_optimizer.zero_grad()
        
        # 1. Train with real images
        # Compute the D losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)
        
        # 2. Train with fake images
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        # move to GPU, if available
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images            
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # train G
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels 
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images 
        # using flipped labels
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
        
        # Print some loss stats
        if batch_i % print_every == 0:
            # append D loss and G loss
            losses.append((d_loss.item(), g_loss.item()))
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    d_scheduler.step()
    g_scheduler.step()
    # AFTER EACH EPOCH    
    # generate and save fake images
    G.eval() # eval mode for generating samples
    # eval mode - batch_norm & drop out behave differently in generating new samples
    # batch_norm should use population statistics instead of batch statistics in eval
    # dropout should not drop any nodes during testing
    
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # switch back to training mode

# Save training generator samples
with open('fake_images.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch [    1/   50] | d_loss: 2.8087 | g_loss: 1.6514
# Epoch [    1/   50] | d_loss: 2.9219 | g_loss: 1.5146
# Epoch [    2/   50] | d_loss: 2.5134 | g_loss: 1.2029
# Epoch [    2/   50] | d_loss: 0.5603 | g_loss: 1.7773
# Epoch [    3/   50] | d_loss: 0.2333 | g_loss: 2.5964
# Epoch [    3/   50] | d_loss: 0.0876 | g_loss: 4.2408
# Epoch [    4/   50] | d_loss: 0.3125 | g_loss: 2.7522
# Epoch [    4/   50] | d_loss: 0.1717 | g_loss: 2.9749
# Epoch [    5/   50] | d_loss: 0.1379 | g_loss: 3.3811
# Epoch [    5/   50] | d_loss: 0.2510 | g_loss: 3.6445
# Epoch [    6/   50] | d_loss: 0.3817 | g_loss: 2.5589
# Epoch [    6/   50] | d_loss: 1.0731 | g_loss: 4.3712
# Epoch [    7/   50] | d_loss: 0.3651 | g_loss: 3.9999
# Epoch [    7/   50] | d_loss: 0.5461 | g_loss: 3.5963
# Epoch [    8/   50] | d_loss: 0.2600 | g_loss: 3.5443
# Epoch [    8/   50] | d_loss: 0.3390 | g_loss: 2.7120
# Epoch [    9/   50] | d_loss: 0.7152 | g_loss: 2.6712
# Epoch [    9/   50] | d_loss: 0.2194 | g_loss: 2.3245
# Epoch [   10/   50] | d_loss: 0.6809 | g_loss: 2.6810
# Epoch [   10/   50] | d_loss: 0.2270 | g_loss: 4.1612
# Epoch [   11/   50] | d_loss: 0.2133 | g_loss: 3.5007
# Epoch [   11/   50] | d_loss: 0.2715 | g_loss: 4.5916
# Epoch [   12/   50] | d_loss: 0.6575 | g_loss: 6.5515
# Epoch [   12/   50] | d_loss: 0.6182 | g_loss: 6.5478
# Epoch [   13/   50] | d_loss: 0.2426 | g_loss: 3.9028
# Epoch [   13/   50] | d_loss: 0.3524 | g_loss: 3.1896
# Epoch [   14/   50] | d_loss: 0.4758 | g_loss: 3.8772
# Epoch [   14/   50] | d_loss: 0.3222 | g_loss: 3.8233
# Epoch [   36/   50] | d_loss: 0.5691 | g_loss: 5.3228
# Epoch [   36/   50] | d_loss: 0.3497 | g_loss: 5.2520
# Epoch [   37/   50] | d_loss: 0.0292 | g_loss: 5.5505
# Epoch [   37/   50] | d_loss: 0.1888 | g_loss: 4.8036
# Epoch [   38/   50] | d_loss: 0.6474 | g_loss: 5.6411
# Epoch [   38/   50] | d_loss: 0.0763 | g_loss: 4.4225
# Epoch [   39/   50] | d_loss: 0.1135 | g_loss: 4.7670
# Epoch [   39/   50] | d_loss: 0.2941 | g_loss: 3.2472
# Epoch [   40/   50] | d_loss: 0.0509 | g_loss: 6.1848
# Epoch [   40/   50] | d_loss: 0.1508 | g_loss: 6.6838
# Epoch [   41/   50] | d_loss: 0.0732 | g_loss: 5.0113
# Epoch [   41/   50] | d_loss: 0.0641 | g_loss: 6.2115
# Epoch [   42/   50] | d_loss: 0.0743 | g_loss: 4.6740
# Epoch [   42/   50] | d_loss: 0.1042 | g_loss: 6.3673
# Epoch [   43/   50] | d_loss: 0.3472 | g_loss: 6.2402
# Epoch [   43/   50] | d_loss: 0.2635 | g_loss: 4.3973
# Epoch [   44/   50] | d_loss: 0.0236 | g_loss: 6.1452
# Epoch [   44/   50] | d_loss: 3.1884 | g_loss: 10.4192
# Epoch [   45/   50] | d_loss: 0.0216 | g_loss: 5.7630
# Epoch [   45/   50] | d_loss: 0.0806 | g_loss: 5.2825
# Epoch [   46/   50] | d_loss: 0.1454 | g_loss: 5.7649
# Epoch [   46/   50] | d_loss: 0.7531 | g_loss: 0.5769
# Epoch [   47/   50] | d_loss: 0.9780 | g_loss: 1.3646
# Epoch [   47/   50] | d_loss: 0.1157 | g_loss: 6.3201
# Epoch [   48/   50] | d_loss: 0.0679 | g_loss: 5.8730
# Epoch [   48/   50] | d_loss: 0.3535 | g_loss: 9.2458
# Epoch [   49/   50] | d_loss: 0.0779 | g_loss: 7.7012
# Epoch [   49/   50] | d_loss: 0.0719 | g_loss: 6.9126
# Epoch [   50/   50] | d_loss: 0.1005 | g_loss: 4.5179
# Epoch [   50/   50] | d_loss: 0.4806 | g_loss: 9.2996

# %%
_ = view_samples(-1, samples)#new result1
#After each epoch , the learning rate of G decreses by 5%, the learning rate of D decreses by 3%
#50 epochs lr=0.0003 try to use higher learning rate
torch.save(D, 'D2.pkl')  # save entire net
torch.save(G, 'G2.pkl')  # save entire net

# %%
# Optimisers, similar to what we did before
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf
lr = 0.0002# Use bigger lr
beta1=0.5
beta2=0.999 # default value

d_lambda = lambda epoch: 0.95 * epoch# After each epoch, the learning rate decrease 5%

g_lambda = lambda epoch: 0.97 * epoch# After each epoch, the learning rate decrease 5%
# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
d_scheduler=optim.lr_scheduler.LambdaLR(d_optimizer, lr_lambda=d_lambda)#define scheduler for d_optimizer and g_optimizer
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])
g_scheduler=optim.lr_scheduler.LambdaLR(g_optimizer, lr_lambda=g_lambda)#define scheduler for d_optimizer and g_optimizer

# Discriminator training
#   Compute the discriminator loss on real, training images
#   Generate fake images
#   Compute the discriminator loss on fake, generated images
#   Add up real and fake loss
#   Perform backpropagation + an optimization step to update the discriminator's weights
#
# Generator training
#   Generate fake images
#   Compute the discriminator loss on fake images, using flipped labels!
#   Perform backpropagation + an optimization step to update the generator's weights


import pickle as pkl # to save intermediate fake images

# training hyperparams
num_epochs = 30 # will run for a 2-4 hours

# keep track of loss and fake samples
samples = []
losses = []
print_every = 300

# Get some fixed data for evaluating the model's performance as we train
# Keep these images constant
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        # important rescaling step
        real_images = scale(real_images)
        
        # train D
        d_optimizer.zero_grad()
        
        # 1. Train with real images
        # Compute the D losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)
        
        # 2. Train with fake images
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        # move to GPU, if available
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images            
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # train G
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels 
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images 
        # using flipped labels
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
        
        # Print some loss stats
        if batch_i % print_every == 0:
            # append D loss and G loss
            losses.append((d_loss.item(), g_loss.item()))
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    d_scheduler.step()
    g_scheduler.step()
    # AFTER EACH EPOCH    
    # generate and save fake images
    G.eval() # eval mode for generating samples
    # eval mode - batch_norm & drop out behave differently in generating new samples
    # batch_norm should use population statistics instead of batch statistics in eval
    # dropout should not drop any nodes during testing
    
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # switch back to training mode

# Save training generator samples
with open('fake_images.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# GPU available for training. Models moved to GPU
# Epoch [    1/   30] | d_loss: 1.3904 | g_loss: 0.6708
# Epoch [    1/   30] | d_loss: 1.3977 | g_loss: 0.6674
# Epoch [    2/   30] | d_loss: 1.4088 | g_loss: 0.8740
# Epoch [    2/   30] | d_loss: 0.3920 | g_loss: 1.8979
# Epoch [    3/   30] | d_loss: 0.7121 | g_loss: 4.4271
# Epoch [    3/   30] | d_loss: 1.4741 | g_loss: 3.8306
# Epoch [    4/   30] | d_loss: 0.8390 | g_loss: 2.9745
# Epoch [    4/   30] | d_loss: 1.1893 | g_loss: 2.3377
# Epoch [    5/   30] | d_loss: 0.3419 | g_loss: 2.5089
# Epoch [    5/   30] | d_loss: 0.2818 | g_loss: 1.9269
# Epoch [    6/   30] | d_loss: 0.9181 | g_loss: 2.7939
# Epoch [    6/   30] | d_loss: 0.8804 | g_loss: 0.9848
# Epoch [    7/   30] | d_loss: 0.7599 | g_loss: 3.5343
# Epoch [    7/   30] | d_loss: 0.7231 | g_loss: 2.4301
# Epoch [    8/   30] | d_loss: 0.4511 | g_loss: 2.3342
# Epoch [    8/   30] | d_loss: 1.0691 | g_loss: 2.9856
# Epoch [    9/   30] | d_loss: 0.5592 | g_loss: 2.0912
# Epoch [    9/   30] | d_loss: 0.9386 | g_loss: 1.8368
# Epoch [   10/   30] | d_loss: 0.6561 | g_loss: 2.3545
# Epoch [   10/   30] | d_loss: 0.6050 | g_loss: 2.3796
# Epoch [   11/   30] | d_loss: 1.7513 | g_loss: 0.8863
# Epoch [   11/   30] | d_loss: 0.4614 | g_loss: 2.1874
# Epoch [   12/   30] | d_loss: 0.7576 | g_loss: 2.2118
# Epoch [   12/   30] | d_loss: 0.4538 | g_loss: 2.0578
# Epoch [   13/   30] | d_loss: 0.3795 | g_loss: 2.2873
# Epoch [   13/   30] | d_loss: 1.3413 | g_loss: 0.8030
# Epoch [   14/   30] | d_loss: 0.6149 | g_loss: 1.0692
# Epoch [   14/   30] | d_loss: 0.3543 | g_loss: 3.1512
# Epoch [   15/   30] | d_loss: 0.8225 | g_loss: 1.4318
# Epoch [   15/   30] | d_loss: 0.3278 | g_loss: 3.6025
# Epoch [   16/   30] | d_loss: 1.2059 | g_loss: 1.9412
# Epoch [   16/   30] | d_loss: 0.4467 | g_loss: 2.7280
# Epoch [   17/   30] | d_loss: 1.4226 | g_loss: 0.9275
# Epoch [   17/   30] | d_loss: 0.9439 | g_loss: 1.4755
# Epoch [   18/   30] | d_loss: 0.6248 | g_loss: 3.9343
# Epoch [   18/   30] | d_loss: 1.6441 | g_loss: 0.8781
# Epoch [   19/   30] | d_loss: 0.4077 | g_loss: 2.4954
# Epoch [   19/   30] | d_loss: 0.5270 | g_loss: 4.1846
# Epoch [   20/   30] | d_loss: 0.6140 | g_loss: 3.7437
# Epoch [   20/   30] | d_loss: 0.8640 | g_loss: 4.7772
# Epoch [   21/   30] | d_loss: 1.8067 | g_loss: 0.7445
# Epoch [   21/   30] | d_loss: 0.3897 | g_loss: 2.0156
# Epoch [   22/   30] | d_loss: 0.3170 | g_loss: 2.0101
# Epoch [   22/   30] | d_loss: 1.4030 | g_loss: 4.6257
# Epoch [   23/   30] | d_loss: 0.4983 | g_loss: 5.0250
# Epoch [   23/   30] | d_loss: 0.2929 | g_loss: 4.3610
# Epoch [   24/   30] | d_loss: 0.9041 | g_loss: 4.0980
# Epoch [   24/   30] | d_loss: 0.1421 | g_loss: 3.4204
# Epoch [   25/   30] | d_loss: 0.7609 | g_loss: 4.8917
# Epoch [   25/   30] | d_loss: 1.0127 | g_loss: 3.5164
# Epoch [   26/   30] | d_loss: 0.1345 | g_loss: 3.5023
# Epoch [   26/   30] | d_loss: 0.3441 | g_loss: 4.2050
# Epoch [   27/   30] | d_loss: 1.1454 | g_loss: 0.9661
# Epoch [   27/   30] | d_loss: 0.7652 | g_loss: 2.1628
# Epoch [   28/   30] | d_loss: 2.4436 | g_loss: 7.5428
# Epoch [   28/   30] | d_loss: 0.1985 | g_loss: 3.2817
# Epoch [   29/   30] | d_loss: 0.0958 | g_loss: 5.0013
# Epoch [   29/   30] | d_loss: 0.4548 | g_loss: 3.1898
# Epoch [   30/   30] | d_loss: 1.0021 | g_loss: 5.0876
# Epoch [   30/   30] | d_loss: 0.3898 | g_loss: 3.4981

# %%
_ = view_samples(-1, samples)#new result1
#try to use less epoch number
#0.95 0.97 lr=0.0002 30 epoch
#still works ok, I don't think this model is worse than the model with epoch number as 50
torch.save(D, 'D3.pkl')  # save entire net
torch.save(G, 'G3.pkl')  # save entire net

# %%
# Optimisers, similar to what we did before
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf
lr = 0.0002# Use bigger lr
beta1=0.5
beta2=0.999 # default value

d_lambda = lambda epoch: 0.95 * epoch# After each epoch, the learning rate decrease 5%

g_lambda = lambda epoch: 0.97 * epoch# After each epoch, the learning rate decrease 5%
# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
d_scheduler=optim.lr_scheduler.LambdaLR(d_optimizer, lr_lambda=d_lambda)#define scheduler for d_optimizer and g_optimizer
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])
g_scheduler=optim.lr_scheduler.LambdaLR(g_optimizer, lr_lambda=g_lambda)#define scheduler for d_optimizer and g_optimizer

# Discriminator training
#   Compute the discriminator loss on real, training images
#   Generate fake images
#   Compute the discriminator loss on fake, generated images
#   Add up real and fake loss
#   Perform backpropagation + an optimization step to update the discriminator's weights
#
# Generator training
#   Generate fake images
#   Compute the discriminator loss on fake images, using flipped labels!
#   Perform backpropagation + an optimization step to update the generator's weights


import pickle as pkl # to save intermediate fake images

# training hyperparams
num_epochs = 50 # will run for a 2-4 hours

# keep track of loss and fake samples
samples = []
losses = []
print_every = 300

# Get some fixed data for evaluating the model's performance as we train
# Keep these images constant
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        # important rescaling step
        real_images = scale(real_images)
        
        # train D
        d_optimizer.zero_grad()
        
        # 1. Train with real images
        # Compute the D losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)
        
        # 2. Train with fake images
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        # move to GPU, if available
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images            
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # train G
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels 
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images 
        # using flipped labels
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
        
        # Print some loss stats
        if batch_i % print_every == 0:
            # append D loss and G loss
            losses.append((d_loss.item(), g_loss.item()))
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    d_scheduler.step()
    g_scheduler.step()
    # AFTER EACH EPOCH    
    # generate and save fake images
    G.eval() # eval mode for generating samples
    # eval mode - batch_norm & drop out behave differently in generating new samples
    # batch_norm should use population statistics instead of batch statistics in eval
    # dropout should not drop any nodes during testing
    
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # switch back to training mode

# Save training generator samples
with open('fake_images.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# GPU available for training. Models moved to GPU
# Epoch [    1/   50] | d_loss: 1.3375 | g_loss: 0.6324
# Epoch [    1/   50] | d_loss: 1.3583 | g_loss: 0.6339
# Epoch [    2/   50] | d_loss: 1.3436 | g_loss: 0.8285
# Epoch [    2/   50] | d_loss: 0.5413 | g_loss: 3.2211
# Epoch [    3/   50] | d_loss: 0.2861 | g_loss: 3.1632
# Epoch [    3/   50] | d_loss: 0.7148 | g_loss: 2.2319
# Epoch [    4/   50] | d_loss: 0.9143 | g_loss: 4.9469
# Epoch [    4/   50] | d_loss: 0.6928 | g_loss: 2.0412
# Epoch [    5/   50] | d_loss: 0.3756 | g_loss: 2.6157
# Epoch [    5/   50] | d_loss: 0.8391 | g_loss: 2.5647
# Epoch [    6/   50] | d_loss: 0.9432 | g_loss: 3.6641
# Epoch [    6/   50] | d_loss: 1.0981 | g_loss: 3.1218
# Epoch [    7/   50] | d_loss: 0.5842 | g_loss: 1.8504
# Epoch [    7/   50] | d_loss: 0.4715 | g_loss: 1.7916
# Epoch [    8/   50] | d_loss: 0.7579 | g_loss: 2.2708
# Epoch [    8/   50] | d_loss: 1.1232 | g_loss: 3.8557
# Epoch [    9/   50] | d_loss: 2.0742 | g_loss: 2.6145
# Epoch [    9/   50] | d_loss: 0.5334 | g_loss: 1.4137
# Epoch [   10/   50] | d_loss: 0.6278 | g_loss: 3.3684
